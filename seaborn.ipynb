# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.jointplot(x='petal_length',y='petal_length',data=df,kind='hex')

# %%
df1=sns.load_dataset("tips")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.jointplot(x='petal_length',y='petal_length',data=df,kind='resid')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df1,hue='smoker')

# %%
list=[[1,2,3,6,5,4,5,5,12,1,23,43]]

# %%
sns.distplot(list,kde=False)

# %%
sns.barplot(x='total_bill',y='tip',data=df1)

# %%
sns.boxplot(x='petal_length',y='petal_width',data=df)

# %%
sns.boxplot('smoker','total_bill', data=df1,palette='rainbow')

# %%
sns.boxplot('smoker','total_bill', data=df1)

# %%
sns.boxplot(x="day", y="total_bill", data=df1,palette='rainbow')

# %%
sns.boxplot(data=df,orient='v')

# %%
sns.boxplot(data=df1)

# %%
sns.boxplot(data=df1,orient='h')

# %%
sns.boxplot(x="petal_length", y="sepal_length", hue="petal_width",data=df)

# %%
# counlplot
sns.countplot('sex',data=df1)

# %%
#barplot
sns.barplot('sex','total_bill',data=df1)

# %%
#boxplot
sns.boxplot('sex','total_bill',data=df1)

# %%
#boxplot
sns.boxplot(x="total_bill", y="day", hue="smoker",data=df1)

# %%
#countplot
sns.violinplot('sex',y='total_bill',data=df1)

# %%
#violinplot
sns.violinplot('petal_length',y="petal_width",data=df,split=True,cut=4)

# %%
#barplot
sns.barplot('sex','total_bill',data=df1)
