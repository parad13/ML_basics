# %%
import cv2 as cv
import numpy as np

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('D:/Paras/Profile/p.jpg')
print(img)
# Out:
# [[[ 35  45  34]
#   [ 32  42  31]
#   [ 38  46  35]
#   ...
#   [255 255 253]
#   [255 255 253]
#   [255 255 253]]
#
#  [[ 33  41  30]
#   [ 32  40  29]
#   [ 38  46  35]
#   ...
#   [255 255 253]
#   [255 255 253]
#   [255 255 253]]
#
#  [[ 37  45  34]
#   [ 39  45  35]
#   [ 46  52  42]
#   ...
#   [255 255 253]
#   [255 255 253]
#   [255 255 253]]
#
#  ...
#
#  [[ 39 145 193]
#   [ 46 152 202]
#   [ 52 156 207]
#   ...
#   [125 207 231]
#   [123 208 229]
#   [121 205 229]]
#
#  [[ 24 130 178]
#   [ 49 153 204]
#   [ 64 168 219]
#   ...
#   [137 219 241]
#   [133 215 237]
#   [124 206 228]]
#
#  [[ 51 156 204]
#   [ 48 152 203]
#   [ 47 151 202]
#   ...
#   [127 207 230]
#   [124 204 227]
#   [125 205 228]]]

# %%
imgplot = plt.imshow(img)

# %%
#Erosion
img = cv.imread('D:/Paras/Profile/p.jpg',0)
kernel = np.ones((5,5) , np.uint8)
erosion = cv.erode(img, kernel, iterations = 1)
plt.imshow(erosion)

# %%
# lum_img = img[500:, 100:]
# plt.imshow(lum_img)

# %%
#Dilation
dilation = cv.dilate(img, kernel, iterations = 1)
plt.imshow(dilation)

# %%
#Opening
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(opening)

# %%
#Closing
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
plt.imshow(closing)

# %%
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.imshow(gradient)

# %%
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(tophat)

# %%
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
plt.imshow(blackhat)
